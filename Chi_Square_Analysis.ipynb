# %% [markdown]
# <a href="https://colab.research.google.com/github/omertahakerem/statistical-analysis-II-homework/blob/main/Chi_Square_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# **TR:**
# Bu çalışmada iki kategorik değişken arasında ilişki olup olmadığı Ki-Kare Bağımsızlık Testi ile incelenmiştir.
#
# **EN:**
# This study examines whether there is a relationship between two categorical variables using the Chi-Square Test of Independence.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Veri oluşturma
data = np.array([[32, 18],
                 [20, 30]])

df = pd.DataFrame(data,
                  index=["Kadin", "Erkek"],
                  columns=["Online", "Magaza"])

print("Contingency Table:")
print(df)
# Out:
# Contingency Table:
#        Online  Magaza
# Kadin      32      18
# Erkek      20      30

# %% [markdown]
# ## Chi-Square Test
#
# **TR:**
# Ki-Kare Bağımsızlık Testi, iki kategorik değişken arasında istatistiksel olarak anlamlı bir ilişki olup olmadığını test eder.
#
# H0: Değişkenler bağımsızdır.
# H1: Değişkenler bağımsız değildir.
#
# **EN:**
# The Chi-Square Test of Independence is used to determine whether there is a statistically significant relationship between two categorical variables.
#
# H0: Variables are independent.
# H1: Variables are not independent.

# %%
# Ki-Kare testi

chi2, p, dof, expected = chi2_contingency(df)

print("Chi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-Value:", p)
# Out:
# Chi-Square Statistic: 4.847756410256411
# Degrees of Freedom: 1
# P-Value: 0.02768211649783557

# %% [markdown]
# ## Expected Frequencies
#
# **TR:**
# Beklenen frekanslar, değişkenlerin bağımsız olduğu varsayımı altında her hücrede beklenen değerleri göstermektedir.
#
# **EN:**
# Expected frequencies show the values expected in each cell under the assumption that the variables are independent.

# %%
expected_df = pd.DataFrame(expected,
                           index=df.index,
                           columns=df.columns)

print(expected_df)
# Out:
#        Online  Magaza
# Kadin    26.0    24.0
# Erkek    26.0    24.0

# %% [markdown]
# ## Conclusion
#
# **TR:**
# Yapılan Ki-Kare Bağımsızlık Testi sonucunda elde edilen p-value değeri 0.027 olarak bulunmuştur. Bu değer 0.05’ten küçük olduğu için H0 hipotezi reddedilir. Buna göre cinsiyet ile alışveriş tercihi arasında istatistiksel olarak anlamlı bir ilişki vardır.
#
# **EN:**
# As a result of the Chi-Square Test of Independence, the p-value was found to be 0.027. Since this value is less than 0.05, the null hypothesis is rejected. Therefore, there is a statistically significant relationship between gender and shopping preference.
